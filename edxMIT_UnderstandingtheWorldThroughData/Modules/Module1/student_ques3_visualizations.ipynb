# %% [markdown]
# <br>
# <font size="+2"> In this notebook, we will be working on questions in Colab Notebooks section in Module 1. </font>
# <br><br>

# %% [markdown]
# In this notebook, we will continue working with `city_temperature.csv` datafile; remember that the format of this datafile is the same as the temperature datafile we were using in the video, it just has many more data points because it includes temperature data for the entire world (i.e. rows).

# %% [markdown]
# <font color='#FF4500' size="+2"> To set up your DataFrame for these questions, run the cell below. </font>

# %%
import pandas as pd
df2 = pd.read_csv("Data/city_temperature.csv")
# Out:
# C:\Users\Cbilinski\AppData\Local\Temp\ipykernel_9484\2726112131.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("Data/city_temperature.csv")

# %% [markdown]
# # Questions on Visualizations

# %% [markdown]
# In this series of questions you will be deciding which datasets match each plot. Create the following cleaned up dataset called `clean`, which is the full temperature dataset without any -99 temperatures. Use the command below (run the cell below), assuming that your full dataset is saved in a DataFrame called df2.

# %%
clean = df2.loc[(df2["AvgTemperature"] != -99)]

# %% [markdown]
# ## Question 1
#
# Create an x-y plot of the average temperature in Paris in the year 2002.

# %%
import matplotlib.pyplot as plt

plt.plot(clean[(clean['City'] == 'Paris') & (clean['Year'] == 2002)]['AvgTemperature'])

# %% [markdown]
# ## Question 2
#
# Create a scatter plot of the average temperature in Tokyo in the year 1996.

# %%
plt.scatter(range(len(clean[(clean['City'] == 'Tokyo') & (clean['Year'] == 1996)]['AvgTemperature'])),clean[(clean['City'] == 'Tokyo') & (df2['Year'] == 1996)]['AvgTemperature'])
# Out:
# C:\Users\Cbilinski\AppData\Local\Temp\ipykernel_9484\1218993893.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.scatter(range(len(clean[(clean['City'] == 'Tokyo') & (clean['Year'] == 1996)]['AvgTemperature'])),clean[(clean['City'] == 'Tokyo') & (df2['Year'] == 1996)]['AvgTemperature'])

# %% [markdown]
# ## Question 3
#
# Create a histogram of the average temperature in the country Sweden in March with 10 bins.

# %%
plt.hist(clean[(clean['Country'] == 'Sweden') & (clean['Month'] == 3)]['AvgTemperature'], bins=10)

#clean[(clean['Country'] == 'Sweden') & (clean['Month'] == 3)]['AvgTemperature']
# Out:
# (array([  4.,  11.,  36.,  59., 125., 214., 179., 124.,  46.,   7.]),
#  array([ 9.5 , 13.79, 18.08, 22.37, 26.66, 30.95, 35.24, 39.53, 43.82,
#         48.11, 52.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Question 4
#
# Create a histogram of the average temperature in the country Sweden in March with 4 bins. Use the histogram to approximate the total number of data points.

# %%
plt.hist(clean[(clean['Country'] == 'Sweden') & (clean['Month'] == 3)]['AvgTemperature'], bins=4)
# Out:
# (array([ 27., 208., 459., 111.]),
#  array([ 9.5  , 20.225, 30.95 , 41.675, 52.4  ]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# ## Question 5
#
# What is the correlation between average temperature and month for the country Japan in the year 2000 and months January through July?

# %%
import seaborn as sns
Jap = clean[(clean['Country'] == 'Japan') & (clean['Year'] == 2000) & (clean['Month'] < 8)]
c_Jap = Jap.corr()
sns.heatmap(c_Jap)
# Out:
# C:\Users\Cbilinski\AppData\Local\Temp\ipykernel_9484\604322434.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c_Jap = Jap.corr()
# <Axes: >

# %%
c_Jap
# Out:
#                    Month       Day  Year  AvgTemperature
# Month           1.000000  0.007604   NaN        0.833035
# Day             0.007604  1.000000   NaN        0.054262
# Year                 NaN       NaN   NaN             NaN
# AvgTemperature  0.833035  0.054262   NaN        1.000000

# %% [markdown]
# ## Question 6
#
# What is the correlation between average temperature and month for the country Argentina in the year 2000 and months January through July?

# %%
Arg = clean[(clean['Country'] == 'Argentina') & (clean['Year'] == 2000) & (clean['Month'] < 8)]
c_Arg = Arg.corr()
sns.heatmap(c_Arg)
# Out:
# C:\Users\Cbilinski\AppData\Local\Temp\ipykernel_9484\2229050937.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c_Arg = Arg.corr()
# <Axes: >

# %%
c_Arg
# Out:
#                    Month       Day  Year  AvgTemperature
# Month           1.000000  0.007604   NaN       -0.894116
# Day             0.007604  1.000000   NaN       -0.104284
# Year                 NaN       NaN   NaN             NaN
# AvgTemperature -0.894116 -0.104284   NaN        1.000000

# %% [markdown]
# ## Question 7
#
# What is the correlation between average temperature and month for the country Colombia in the year 2000? Round to 2 decimal places.

# %%
Col = clean[(clean['Country'] == 'Colombia') & (clean['Year'] == 2000)]
c_Col = Col.corr()
sns.heatmap(c_Col)
c_Col
# Out:
# C:\Users\Cbilinski\AppData\Local\Temp\ipykernel_9484\899956465.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c_Col = Col.corr()
#                    Month       Day  Year  AvgTemperature
# Month           1.000000  0.000691   NaN       -0.017692
# Day             0.000691  1.000000   NaN        0.032431
# Year                 NaN       NaN   NaN             NaN
# AvgTemperature -0.017692  0.032431   NaN        1.000000
