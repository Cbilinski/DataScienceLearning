# %% [markdown]
# ### Set-Up
# Set up Colab to read the data from your course Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
#os.chdir("/content/drive/My Drive/AIMOOC")
# !ls
# Out:
# Capstone
# Data
# student_lec1_linear_regression.ipynb
# student_lec2_R2.ipynb
# student_lec3_predict.ipynb
# student_lec4_multiple_linear_regression.ipynb
# student_lec5_linear_regression_quadratic.ipynb
# student_lec6_overfitting.ipynb
# student_ques1_linear_regression.ipynb
# student_ques2_R2.ipynb
# student_ques3_predict.ipynb
# student_ques6_polynomial.ipynb

# %% [markdown]
# ## R2

# %%
import pandas as pd
import sklearn.linear_model as lm 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

pd.set_option('display.max_columns', 500)
df = pd.read_csv("Data/growth_chart_yearly.csv")


x = df[["age_months"]]
y1 = df["weight_lb"]
y2 = df["height_ft"]

def do_fit(x, y):
  # do linear regression and print the slope and y-intercept
  lin_reg = lm.LinearRegression()
  lin_reg.fit(x, y) 
  print('\n',y.name)
  print('Coefficients:', lin_reg.coef_)
  print('Intercept:', lin_reg.intercept_)

  # create a new figure, plot all the data points and the best fit line
  #plt.figure()
  plt.scatter(x, y)
  ypred = lin_reg.predict(x)
  plt.plot(x, ypred)

  # calculate and print mean squared error and R2
  print("MSQERR", mean_squared_error(y, ypred))
  print("R2", lin_reg.score(x, y))
  
do_fit(x, y1)
plt.xlabel("Age in months")
plt.ylabel("Weight in lb")
plt.title("Weight Values for 10 Ages (with Best Fit Line)")

do_fit(x, y2)
plt.xlabel("Age in months")
plt.ylabel("Height in ft")
plt.title("Height Values for 10 Ages (with Best Fit Line)")
# Out:
#  weight_lb
# Coefficients: [0.64709097]
# Intercept: 2.2526944000000384
# MSQERR 40.687398817853946
# R2 0.9799616526248912
#
#  height_ft
# Coefficients: [0.01439576]
# Intercept: 2.7312080054666676
# MSQERR 0.03351183079131616
# R2 0.967090636698571
# Text(0.5, 1.0, 'Height Values for 10 Ages (with Best Fit Line)')
