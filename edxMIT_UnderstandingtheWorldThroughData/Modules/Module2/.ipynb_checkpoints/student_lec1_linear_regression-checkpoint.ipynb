# %% [markdown]
# ### Set-Up
# Set up Colab to read the data from your course Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive/', force_remount=True)

# %%
import os
#os.chdir("/content/drive/My Drive/AIMOOC")
# !ls
# Out:
# Capstone
# Data
# student_lec1_linear_regression.ipynb
# student_lec2_R2.ipynb
# student_lec3_predict.ipynb
# student_lec4_multiple_linear_regression.ipynb
# student_lec5_linear_regression_quadratic.ipynb
# student_lec6_overfitting.ipynb
# student_ques1_linear_regression.ipynb
# student_ques2_R2.ipynb
# student_ques3_predict.ipynb
# student_ques6_polynomial.ipynb

# %% [markdown]
# ### Reading Data
# Read in the data file into a DataFrame where one column is the gallons of gas used and the second column is the miles traveled on that amount of gas for a Toyota Corolla.

# %%
import pandas as pd
df = pd.read_csv("Data/car_toyota_corolla.csv")
df
# Out:
#     Gallons  Miles
# 0         0      0
# 1         1     32
# 2         2     52
# 3         3     77
# 4         4    116
# 5         5    126
# 6         6    172
# 7         7    203
# 8         8    232
# 9         9    248
# 10       10    305
# 11       11    319
# 12       12    369
# 13       13    377
# 14       14    438
# 15       15    505
# 16       16    464

# %% [markdown]
# Recall that when we manually tried to fit a line to this data by picking arbitrary sets of 2 points, we got all sorts of lines. But the line that best represents all the data is the one that minimizes the mean-squared-error.

# %% [markdown]
# ### Finding the Best Fit Line
# Use linear regression to find the formula for the best fit line.

# %%
import sklearn.linear_model as lm

# %%
x = df[["Gallons"]]
y = df["Miles"]
lin_reg = lm.LinearRegression()
lin_reg.fit(x, y) 
print('Coefficients:', lin_reg.coef_)
print('Intercept:', lin_reg.intercept_)
df
# Out:
# Coefficients: [31.22794118]
# Intercept: -12.470588235294173
#     Gallons  Miles
# 0         0      0
# 1         1     32
# 2         2     52
# 3         3     77
# 4         4    116
# 5         5    126
# 6         6    172
# 7         7    203
# 8         8    232
# 9         9    248
# 10       10    305
# 11       11    319
# 12       12    369
# 13       13    377
# 14       14    438
# 15       15    505
# 16       16    464

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)
ypred = lin_reg.predict(x)
plt.plot(x, ypred, color="blue")
plt.xlabel("Gallons")
plt.ylabel("Miles")
plt.title("How Many Miles Toyota Corolla Travels on Some Number of Gallons")
# Out:
# Text(0.5, 1.0, 'How Many Miles Toyota Corolla Travels on Some Number of Gallons')

# %%
plt.scatter(x, y)
y2 = lin_reg.coef_ * x + lin_reg.intercept_
plt.plot(x, y2, color="orange")

plt.xlabel("Gallons")
plt.ylabel("Miles")
plt.title("How Many Miles Toyota Corolla Travels on Some Number of Gallons")
# Out:
# Text(0.5, 1.0, 'How Many Miles Toyota Corolla Travels on Some Number of Gallons')

# %% [markdown]
# ## Multicar Dataset

# %%
df2 = pd.read_csv("Data/multicar.csv")
df2
# Out:
#            Car Type  Gallons  Miles
# 0    Toyota Corolla        0      0
# 1    Toyota Corolla        1     32
# 2    Toyota Corolla        2     52
# 3    Toyota Corolla        3     77
# 4    Toyota Corolla        4    116
# ..              ...      ...    ...
# 131      Audi 5000s       12    376
# 132      Audi 5000s       13    454
# 133      Audi 5000s       14    554
# 134      Audi 5000s       15    572
# 135      Audi 5000s       16    484
#
# [136 rows x 3 columns]

# %%
plt.scatter(df2["Gallons"], df2["Miles"])
plt.xlabel("Gallons")
plt.ylabel("Miles")
plt.title("How Many Miles a Car Runs on Some Number of Gallons (for 8 Cars)")
# Out:
# Text(0.5, 1.0, 'How Many Miles a Car Runs on Some Number of Gallons (for 8 Cars)')

# %%
x2 = df2[["Gallons"]]
y2 = df2["Miles"]
lin_reg2 = lm.LinearRegression()
lin_reg2.fit(x2, y2) 
print('Coefficients:', lin_reg2.coef_)
print('Intercept:', lin_reg2.intercept_)
# Out:
# Coefficients: [30.13051471]
# Intercept: -4.551470588235304

# %%
plt.scatter(x2, y2)
ypred2 = lin_reg2.predict(x2)
plt.plot(x2, ypred2, color="blue")
plt.xlabel("Gallons")
plt.ylabel("Miles")
plt.title("How Many Miles 8 Different Cars Run (and Best Fit Line)")
# Out:
# Text(0.5, 1.0, 'How Many Miles 8 Different Cars Run (and Best Fit Line)')
